# %% [markdown]
# ## Auction Duration Stats
# ### By: Brianj (https://twitter.com/pbrianandj)

# %%
from matplotlib import pyplot as plt

# %%
from python_graphql_client import GraphqlClient
import numpy as np

# Instantiate the client with an endpoint.
client = GraphqlClient(endpoint="https://api.thegraph.com/subgraphs/name/nounsdao/nouns-subgraph")

# %%
# Create the query string and variables required for the request.
query = """
    {
  auctions(first: 500, orderBy: id) {
    id,
    startTime
    endTime
    bids {
        id
        blockTimestamp
        blockNumber
    }
  }
}
"""
# Synchronous request
data = client.execute(query=query)

# %%
diff = []
auction_id = []

pairs = []
for auction in data['data']['auctions']:
    duration = (int(auction['endTime']) - int(auction['startTime']))/(3600)
    diff.append(duration)
    auction_id.append(auction['id'])
    pairs.append((int(auction['id']), duration))

# %% [markdown]
# ## Longest Auction

# %%
print(f"Longest auction duration (hours): {max(diff)}")
# Out:
# Longest auction duration (hours): 24.825555555555557

# %%
print(f"Longest auction: {auction_id[diff.index(max(diff))]}")
# Out:
# Longest auction: 99

# %% [markdown]
# ## Auction Duration Histogram

# %%
plt.figure(figsize=(15,10))
plt.title("Auction duration historgram (hours)")
plt.hist(diff)
plt.xlabel('Duration (hours)')
plt.ylabel('Number of auctions')
# Out:
# Text(0, 0.5, 'Number of auctions')

# %% [markdown]
# ## Auction Duration vs Time

# %%
pairs = sorted(pairs, key=lambda x: x[0])
auction_ids, durations = zip(*pairs)
plt.figure(figsize=(15,10))
plt.title("Auction duration (hours) vs time")
plt.plot(durations)
plt.ylabel('Duration (hours)')
plt.xlabel('Auction id')
# Out:
# Text(0.5, 0, 'Auction id')

# %%
def moving_average(a, n=7) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

# %%
plt.figure(figsize=(15,10))
plt.title("Auction duration (hours) vs time -- smoothed")
plt.plot(moving_average(durations))
plt.ylabel('Duration (hours)')
plt.xlabel('Auction id')
# Out:
# Text(0.5, 0, 'Auction id')

# %% [markdown]
# ## Time difference between last bid of auction i and start of auction i + 1

# %%
auctions = []

for auction in data['data']['auctions']:
    bids = auction['bids']
    last_bid = max(map(lambda x: int(x['blockTimestamp']), bids))
    
    if int(auction['id']) % 10 == 0:
        continue
    auctions.append(
        {
            "auction_id": int(auction['id']),
            "start_time": int(auction['startTime']),
            "last_bid_time": last_bid,
        }
    )

auctions = sorted(auctions, key=lambda x: x['start_time'])

# %%
diffs = []
for i in range(len(auctions) - 1):
    diffs.append(
        (i, (auctions[i + 1]['start_time'] - auctions[i]['last_bid_time']) / 60, auctions[i])
    )

# %%
sorted(diffs, key=lambda x: x[1])[-2]
# Out:
# (139,
#  1438.75,
#  {'auction_id': 155, 'start_time': 1640611817, 'last_bid_time': 1640611935})

# %%
minutes_diff = list(map(lambda x: x[1], diffs))

# %%
plt.figure(figsize=(15,10))
plt.title("Time to mint next Noun (minutes) histogram")
plt.hist(minutes_diff)
plt.xlabel('Time to mint next Noun (minutes)')
plt.ylabel('Number of auctions')
# Out:
# Text(0, 0.5, 'Number of auctions')

# %%
plt.figure(figsize=(15,10))
plt.title("Time to mint next Noun (minutes) histogram")
plt.hist(minutes_diff)
plt.xlabel('Time to mint next Noun (minutes)')
plt.ylabel('Log(Number of auctions)')
plt.yscale('log')

# %% [markdown]
# ## Unseen Traits

# %%
# Create the query string and variables required for the request.
query = """
    {
  nouns(first: 1000 orderBy: id orderDirection: asc) {
  id
  seed {
      body
      head
      glasses
  }
  }
}
"""
# Synchronous request
data = client.execute(query=query)

# %%
# These are using the pre 8-8 numbers
TOTAL_HEADS = 234
TOTAL_GLASSES = 21
TOTAL_BODIES = 30

# %%
data['data']['nouns']
# Out:
# [{'id': '0', 'seed': {'body': '14', 'head': '94', 'glasses': '18'}},
#  {'id': '1', 'seed': {'body': '20', 'head': '88', 'glasses': '14'}},
#  {'id': '10', 'seed': {'body': '7', 'head': '103', 'glasses': '11'}},
#  {'id': '100', 'seed': {'body': '17', 'head': '59', 'glasses': '19'}},
#  {'id': '101', 'seed': {'body': '18', 'head': '27', 'glasses': '14'}},
#  {'id': '102', 'seed': {'body': '17', 'head': '98', 'glasses': '10'}},
#  {'id': '103', 'seed': {'body': '0', 'head': '111', 'glasses': '12'}},
#  {'id': '104', 'seed': {'body': '11', 'head': '227', 'glasses': '13'}},
#  {'id': '105', 'seed': {'body': '10', 'head': '129', 'glasses': '7'}},
#  {'id': '106', 'seed': {'body': '0', 'head': '230', 'glasses': '16'}},
#  {'id': '107', 'seed': {'body': '20', 'head': '37', 'glasses': '7'}},
#  {'id': '108', 'seed': {'body': '18', 'head': '56', 'glasses': '19'}},
#  {'id': '109', 'seed': {'body': '3', 'head': '198', 'glasses': '9'}},
#  {'id': '11', 'seed': {'body': '21', 'head': '34', 'glasses': '14'}},
#  {'id': '110', 'seed': {'body': '8', 'head': '137', 'glasses': '6'}},
#  {'id': '111', 'seed': {'body': '7', 'head': '173', 'glasses': '18'}},
#  {'id': '112', 'seed': {'body': '6', 'head': '76', 'glasses': '8'}},
#  {'id': '113', 'seed': {'body': '2', 'head': '74', 'glasses': '10'}},
#  {'id': '114', 'seed': {'body': '8', 'head': '142', 'glasses': '16'}},
#  {'id': '115', 'seed': {'body': '13', 'head': '65', 'glasses': '20'}},
#  {'id': '116', 'seed': {'body': '28', 'head': '95', 'glasses': '15'}},
#  {'id': '117', 'seed': {'body': '5', 'head': '40', 'glasses': '5'}},
#  {'id': '118', 'seed': {'body': '10', 'head': '191', 'glasses': '5'}},
#  {'id': '119', 'seed': {'body': '22', 'head': '2', 'glasses': '4'}},
#  {'id': '12', 'seed': {'body': '1', 'head': '11', 'glasses': '12'}},
#  {'id': '120', 'seed': {'body': '21', 'head': '32', 'glasses': '2'}},
#  {'id': '121', 'seed': {'body': '18', 'head': '186', 'glasses': '17'}},
#  {'id': '122', 'seed': {'body': '18', 'head': '91', 'glasses': '20'}},
#  {'id': '123', 'seed': {'body': '0', 'head': '64', 'glasses': '20'}},
#  {'id': '124', 'seed': {'body': '2', 'head': '76', 'glasses': '20'}},
#  {'id': '125', 'seed': {'body': '23', 'head': '164', 'glasses': '17'}},
#  {'id': '126', 'seed': {'body': '20', 'head': '180', 'glasses': '13'}},
#  {'id': '127', 'seed': {'body': '27', 'head': '231', 'glasses': '1'}},
#  {'id': '128', 'seed': {'body': '2', 'head': '145', 'glasses': '0'}},
#  {'id': '129', 'seed': {'body': '15', 'head': '35', 'glasses': '2'}},
#  {'id': '13', 'seed': {'body': '11', 'head': '210', 'glasses': '13'}},
#  {'id': '130', 'seed': {'body': '29', 'head': '80', 'glasses': '17'}},
#  {'id': '131', 'seed': {'body': '3', 'head': '193', 'glasses': '11'}},
#  {'id': '132', 'seed': {'body': '19', 'head': '123', 'glasses': '12'}},
#  {'id': '133', 'seed': {'body': '8', 'head': '209', 'glasses': '6'}},
#  {'id': '134', 'seed': {'body': '9', 'head': '215', 'glasses': '0'}},
#  {'id': '135', 'seed': {'body': '24', 'head': '23', 'glasses': '17'}},
#  {'id': '136', 'seed': {'body': '1', 'head': '6', 'glasses': '19'}},
#  {'id': '137', 'seed': {'body': '17', 'head': '223', 'glasses': '19'}},
#  {'id': '138', 'seed': {'body': '5', 'head': '34', 'glasses': '6'}},
#  {'id': '139', 'seed': {'body': '7', 'head': '120', 'glasses': '8'}},
#  {'id': '14', 'seed': {'body': '12', 'head': '31', 'glasses': '20'}},
#  {'id': '140', 'seed': {'body': '28', 'head': '125', 'glasses': '20'}},
#  {'id': '141', 'seed': {'body': '27', 'head': '74', 'glasses': '7'}},
#  {'id': '142', 'seed': {'body': '15', 'head': '32', 'glasses': '16'}},
#  {'id': '143', 'seed': {'body': '21', 'head': '185', 'glasses': '11'}},
#  {'id': '144', 'seed': {'body': '12', 'head': '34', 'glasses': '3'}},
#  {'id': '145', 'seed': {'body': '9', 'head': '203', 'glasses': '8'}},
#  {'id': '146', 'seed': {'body': '2', 'head': '197', 'glasses': '15'}},
#  {'id': '147', 'seed': {'body': '23', 'head': '167', 'glasses': '18'}},
#  {'id': '148', 'seed': {'body': '12', 'head': '163', 'glasses': '0'}},
#  {'id': '149', 'seed': {'body': '26', 'head': '45', 'glasses': '6'}},
#  {'id': '15', 'seed': {'body': '9', 'head': '155', 'glasses': '12'}},
#  {'id': '150', 'seed': {'body': '19', 'head': '202', 'glasses': '1'}},
#  {'id': '151', 'seed': {'body': '7', 'head': '223', 'glasses': '5'}},
#  {'id': '152', 'seed': {'body': '9', 'head': '56', 'glasses': '18'}},
#  {'id': '153', 'seed': {'body': '6', 'head': '206', 'glasses': '5'}},
#  {'id': '154', 'seed': {'body': '10', 'head': '37', 'glasses': '14'}},
#  {'id': '155', 'seed': {'body': '23', 'head': '114', 'glasses': '3'}},
#  {'id': '156', 'seed': {'body': '12', 'head': '47', 'glasses': '10'}},
#  {'id': '157', 'seed': {'body': '2', 'head': '185', 'glasses': '16'}},
#  {'id': '158', 'seed': {'body': '18', 'head': '116', 'glasses': '16'}},
#  {'id': '159', 'seed': {'body': '23', 'head': '105', 'glasses': '12'}},
#  {'id': '16', 'seed': {'body': '20', 'head': '168', 'glasses': '16'}},
#  {'id': '160', 'seed': {'body': '21', 'head': '199', 'glasses': '5'}},
#  {'id': '161', 'seed': {'body': '12', 'head': '138', 'glasses': '9'}},
#  {'id': '162', 'seed': {'body': '13', 'head': '201', 'glasses': '13'}},
#  {'id': '163', 'seed': {'body': '29', 'head': '212', 'glasses': '11'}},
#  {'id': '164', 'seed': {'body': '16', 'head': '159', 'glasses': '10'}},
#  {'id': '165', 'seed': {'body': '22', 'head': '194', 'glasses': '11'}},
#  {'id': '166', 'seed': {'body': '0', 'head': '213', 'glasses': '4'}},
#  {'id': '167', 'seed': {'body': '1', 'head': '230', 'glasses': '11'}},
#  {'id': '168', 'seed': {'body': '0', 'head': '170', 'glasses': '17'}},
#  {'id': '169', 'seed': {'body': '12', 'head': '104', 'glasses': '18'}},
#  {'id': '17', 'seed': {'body': '25', 'head': '166', 'glasses': '14'}},
#  {'id': '170', 'seed': {'body': '19', 'head': '70', 'glasses': '12'}},
#  {'id': '171', 'seed': {'body': '22', 'head': '158', 'glasses': '8'}},
#  {'id': '172', 'seed': {'body': '1', 'head': '35', 'glasses': '8'}},
#  {'id': '173', 'seed': {'body': '11', 'head': '222', 'glasses': '17'}},
#  {'id': '174', 'seed': {'body': '9', 'head': '128', 'glasses': '4'}},
#  {'id': '175', 'seed': {'body': '15', 'head': '140', 'glasses': '3'}},
#  {'id': '176', 'seed': {'body': '22', 'head': '173', 'glasses': '8'}},
#  {'id': '177', 'seed': {'body': '6', 'head': '36', 'glasses': '11'}},
#  {'id': '178', 'seed': {'body': '10', 'head': '106', 'glasses': '19'}},
#  {'id': '179', 'seed': {'body': '0', 'head': '11', 'glasses': '9'}},
#  {'id': '18', 'seed': {'body': '5', 'head': '29', 'glasses': '18'}},
#  {'id': '180', 'seed': {'body': '2', 'head': '70', 'glasses': '19'}},
#  {'id': '181', 'seed': {'body': '14', 'head': '15', 'glasses': '4'}},
#  {'id': '182', 'seed': {'body': '20', 'head': '16', 'glasses': '8'}},
#  {'id': '183', 'seed': {'body': '8', 'head': '69', 'glasses': '7'}},
#  {'id': '184', 'seed': {'body': '24', 'head': '14', 'glasses': '1'}},
#  {'id': '185', 'seed': {'body': '8', 'head': '9', 'glasses': '12'}},
#  {'id': '186', 'seed': {'body': '22', 'head': '168', 'glasses': '10'}},
#  {'id': '187', 'seed': {'body': '17', 'head': '169', 'glasses': '10'}},
#  {'id': '188', 'seed': {'body': '12', 'head': '219', 'glasses': '7'}},
#  {'id': '189', 'seed': {'body': '26', 'head': '189', 'glasses': '10'}},
#  {'id': '19', 'seed': {'body': '5', 'head': '56', 'glasses': '18'}},
#  {'id': '190', 'seed': {'body': '11', 'head': '19', 'glasses': '11'}},
#  {'id': '191', 'seed': {'body': '26', 'head': '154', 'glasses': '6'}},
#  {'id': '192', 'seed': {'body': '12', 'head': '188', 'glasses': '9'}},
#  {'id': '193', 'seed': {'body': '9', 'head': '178', 'glasses': '12'}},
#  {'id': '194', 'seed': {'body': '17', 'head': '28', 'glasses': '4'}},
#  {'id': '195', 'seed': {'body': '10', 'head': '85', 'glasses': '16'}},
#  {'id': '196', 'seed': {'body': '9', 'head': '141', 'glasses': '7'}},
#  {'id': '197', 'seed': {'body': '9', 'head': '172', 'glasses': '19'}},
#  {'id': '198', 'seed': {'body': '17', 'head': '52', 'glasses': '8'}},
#  {'id': '199', 'seed': {'body': '22', 'head': '132', 'glasses': '9'}},
#  {'id': '2', 'seed': {'body': '3', 'head': '157', 'glasses': '20'}},
#  {'id': '20', 'seed': {'body': '16', 'head': '114', 'glasses': '17'}},
#  {'id': '200', 'seed': {'body': '23', 'head': '60', 'glasses': '13'}},
#  {'id': '201', 'seed': {'body': '16', 'head': '83', 'glasses': '2'}},
#  {'id': '202', 'seed': {'body': '10', 'head': '129', 'glasses': '17'}},
#  {'id': '203', 'seed': {'body': '10', 'head': '220', 'glasses': '15'}},
#  {'id': '204', 'seed': {'body': '2', 'head': '21', 'glasses': '13'}},
#  {'id': '205', 'seed': {'body': '26', 'head': '212', 'glasses': '3'}},
#  {'id': '206', 'seed': {'body': '28', 'head': '211', 'glasses': '15'}},
#  {'id': '207', 'seed': {'body': '6', 'head': '224', 'glasses': '6'}},
#  {'id': '208', 'seed': {'body': '5', 'head': '228', 'glasses': '0'}},
#  {'id': '209', 'seed': {'body': '5', 'head': '216', 'glasses': '2'}},
#  {'id': '21', 'seed': {'body': '24', 'head': '80', 'glasses': '0'}},
#  {'id': '210', 'seed': {'body': '13', 'head': '225', 'glasses': '19'}},
#  {'id': '211', 'seed': {'body': '10', 'head': '14', 'glasses': '0'}},
#  {'id': '212', 'seed': {'body': '10', 'head': '21', 'glasses': '4'}},
#  {'id': '213', 'seed': {'body': '17', 'head': '143', 'glasses': '2'}},
#  {'id': '214', 'seed': {'body': '12', 'head': '18', 'glasses': '14'}},
#  {'id': '215', 'seed': {'body': '9', 'head': '129', 'glasses': '3'}},
#  {'id': '216', 'seed': {'body': '26', 'head': '110', 'glasses': '3'}},
#  {'id': '217', 'seed': {'body': '29', 'head': '146', 'glasses': '10'}},
#  {'id': '218', 'seed': {'body': '16', 'head': '138', 'glasses': '0'}},
#  {'id': '219', 'seed': {'body': '14', 'head': '121', 'glasses': '11'}},
#  {'id': '22', 'seed': {'body': '2', 'head': '213', 'glasses': '10'}},
#  {'id': '220', 'seed': {'body': '22', 'head': '226', 'glasses': '17'}},
#  {'id': '221', 'seed': {'body': '6', 'head': '42', 'glasses': '12'}},
#  {'id': '222', 'seed': {'body': '23', 'head': '69', 'glasses': '17'}},
#  {'id': '223', 'seed': {'body': '13', 'head': '157', 'glasses': '17'}},
#  {'id': '224', 'seed': {'body': '10', 'head': '11', 'glasses': '7'}},
#  {'id': '225', 'seed': {'body': '12', 'head': '98', 'glasses': '18'}},
#  {'id': '226', 'seed': {'body': '4', 'head': '214', 'glasses': '8'}},
#  {'id': '227', 'seed': {'body': '22', 'head': '97', 'glasses': '15'}},
#  {'id': '228', 'seed': {'body': '7', 'head': '150', 'glasses': '11'}},
#  {'id': '229', 'seed': {'body': '5', 'head': '77', 'glasses': '7'}},
#  {'id': '23', 'seed': {'body': '6', 'head': '4', 'glasses': '10'}},
#  {'id': '230', 'seed': {'body': '3', 'head': '177', 'glasses': '12'}},
#  {'id': '231', 'seed': {'body': '7', 'head': '57', 'glasses': '19'}},
#  {'id': '232', 'seed': {'body': '7', 'head': '93', 'glasses': '20'}},
#  {'id': '233', 'seed': {'body': '7', 'head': '52', 'glasses': '9'}},
#  {'id': '234', 'seed': {'body': '29', 'head': '77', 'glasses': '18'}},
#  {'id': '235', 'seed': {'body': '15', 'head': '81', 'glasses': '5'}},
#  {'id': '236', 'seed': {'body': '4', 'head': '179', 'glasses': '13'}},
#  {'id': '237', 'seed': {'body': '15', 'head': '210', 'glasses': '6'}},
#  {'id': '238', 'seed': {'body': '18', 'head': '163', 'glasses': '3'}},
#  {'id': '239', 'seed': {'body': '21', 'head': '205', 'glasses': '13'}},
#  {'id': '24', 'seed': {'body': '13', 'head': '197', 'glasses': '20'}},
#  {'id': '240', 'seed': {'body': '2', 'head': '212', 'glasses': '3'}},
#  {'id': '241', 'seed': {'body': '11', 'head': '47', 'glasses': '11'}},
#  {'id': '242', 'seed': {'body': '28', 'head': '113', 'glasses': '16'}},
#  {'id': '243', 'seed': {'body': '24', 'head': '156', 'glasses': '0'}},
#  {'id': '244', 'seed': {'body': '8', 'head': '74', 'glasses': '11'}},
#  {'id': '245', 'seed': {'body': '24', 'head': '133', 'glasses': '8'}},
#  {'id': '246', 'seed': {'body': '12', 'head': '188', 'glasses': '8'}},
#  {'id': '247', 'seed': {'body': '2', 'head': '168', 'glasses': '4'}},
#  {'id': '248', 'seed': {'body': '24', 'head': '196', 'glasses': '16'}},
#  {'id': '249', 'seed': {'body': '21', 'head': '92', 'glasses': '11'}},
#  {'id': '25', 'seed': {'body': '18', 'head': '203', 'glasses': '8'}},
#  {'id': '250', 'seed': {'body': '9', 'head': '159', 'glasses': '17'}},
#  {'id': '251', 'seed': {'body': '2', 'head': '13', 'glasses': '13'}},
#  {'id': '252', 'seed': {'body': '21', 'head': '1', 'glasses': '6'}},
#  {'id': '253', 'seed': {'body': '12', 'head': '65', 'glasses': '16'}},
#  {'id': '254', 'seed': {'body': '2', 'head': '203', 'glasses': '19'}},
#  {'id': '255', 'seed': {'body': '14', 'head': '81', 'glasses': '9'}},
#  {'id': '256', 'seed': {'body': '29', 'head': '172', 'glasses': '18'}},
#  {'id': '257', 'seed': {'body': '24', 'head': '47', 'glasses': '14'}},
#  {'id': '258', 'seed': {'body': '10', 'head': '157', 'glasses': '14'}},
#  {'id': '259', 'seed': {'body': '1', 'head': '106', 'glasses': '4'}},
#  {'id': '26', 'seed': {'body': '17', 'head': '41', 'glasses': '15'}},
#  {'id': '260', 'seed': {'body': '2', 'head': '224', 'glasses': '3'}},
#  {'id': '261', 'seed': {'body': '19', 'head': '161', 'glasses': '12'}},
#  {'id': '262', 'seed': {'body': '0', 'head': '9', 'glasses': '7'}},
#  {'id': '263', 'seed': {'body': '18', 'head': '60', 'glasses': '5'}},
#  {'id': '264', 'seed': {'body': '12', 'head': '208', 'glasses': '5'}},
#  {'id': '265', 'seed': {'body': '0', 'head': '110', 'glasses': '18'}},
#  {'id': '266', 'seed': {'body': '10', 'head': '41', 'glasses': '2'}},
#  {'id': '267', 'seed': {'body': '23', 'head': '201', 'glasses': '11'}},
#  {'id': '268', 'seed': {'body': '16', 'head': '82', 'glasses': '14'}},
#  {'id': '269', 'seed': {'body': '18', 'head': '30', 'glasses': '5'}},
#  {'id': '27', 'seed': {'body': '27', 'head': '111', 'glasses': '0'}},
#  {'id': '270', 'seed': {'body': '24', 'head': '86', 'glasses': '13'}},
#  {'id': '271', 'seed': {'body': '4', 'head': '122', 'glasses': '12'}},
#  {'id': '272', 'seed': {'body': '7', 'head': '155', 'glasses': '13'}},
#  {'id': '273', 'seed': {'body': '6', 'head': '181', 'glasses': '8'}},
#  {'id': '274', 'seed': {'body': '26', 'head': '10', 'glasses': '4'}},
#  {'id': '275', 'seed': {'body': '14', 'head': '78', 'glasses': '5'}},
#  {'id': '276', 'seed': {'body': '23', 'head': '86', 'glasses': '0'}},
#  {'id': '277', 'seed': {'body': '29', 'head': '225', 'glasses': '20'}},
#  {'id': '278', 'seed': {'body': '5', 'head': '32', 'glasses': '9'}},
#  {'id': '279', 'seed': {'body': '20', 'head': '160', 'glasses': '8'}},
#  {'id': '28', 'seed': {'body': '16', 'head': '90', 'glasses': '15'}},
#  {'id': '280', 'seed': {'body': '2', 'head': '68', 'glasses': '9'}},
#  {'id': '281', 'seed': {'body': '19', 'head': '126', 'glasses': '1'}},
#  {'id': '282', 'seed': {'body': '12', 'head': '75', 'glasses': '2'}},
#  {'id': '283', 'seed': {'body': '18', 'head': '59', 'glasses': '4'}},
#  {'id': '284', 'seed': {'body': '15', 'head': '163', 'glasses': '13'}},
#  {'id': '285', 'seed': {'body': '14', 'head': '17', 'glasses': '9'}},
#  {'id': '286', 'seed': {'body': '3', 'head': '25', 'glasses': '14'}},
#  {'id': '287', 'seed': {'body': '4', 'head': '200', 'glasses': '4'}},
#  {'id': '288', 'seed': {'body': '23', 'head': '91', 'glasses': '12'}},
#  {'id': '289', 'seed': {'body': '9', 'head': '108', 'glasses': '8'}},
#  {'id': '29', 'seed': {'body': '20', 'head': '136', 'glasses': '1'}},
#  {'id': '290', 'seed': {'body': '14', 'head': '51', 'glasses': '2'}},
#  {'id': '291', 'seed': {'body': '24', 'head': '229', 'glasses': '8'}},
#  {'id': '292', 'seed': {'body': '22', 'head': '160', 'glasses': '6'}},
#  {'id': '293', 'seed': {'body': '19', 'head': '93', 'glasses': '17'}},
#  {'id': '294', 'seed': {'body': '27', 'head': '108', 'glasses': '5'}},
#  {'id': '295', 'seed': {'body': '29', 'head': '75', 'glasses': '5'}},
#  {'id': '296', 'seed': {'body': '12', 'head': '66', 'glasses': '20'}},
#  {'id': '297', 'seed': {'body': '14', 'head': '63', 'glasses': '16'}},
#  {'id': '298', 'seed': {'body': '3', 'head': '92', 'glasses': '19'}},
#  {'id': '299', 'seed': {'body': '1', 'head': '67', 'glasses': '16'}},
#  {'id': '3', 'seed': {'body': '6', 'head': '21', 'glasses': '7'}},
#  {'id': '30', 'seed': {'body': '17', 'head': '115', 'glasses': '15'}},
#  {'id': '300', 'seed': {'body': '20', 'head': '19', 'glasses': '8'}},
#  {'id': '301', 'seed': {'body': '14', 'head': '47', 'glasses': '11'}},
#  {'id': '302', 'seed': {'body': '13', 'head': '132', 'glasses': '11'}},
#  {'id': '303', 'seed': {'body': '24', 'head': '214', 'glasses': '10'}},
#  {'id': '304', 'seed': {'body': '12', 'head': '52', 'glasses': '4'}},
#  {'id': '305', 'seed': {'body': '10', 'head': '131', 'glasses': '3'}},
#  {'id': '306', 'seed': {'body': '3', 'head': '68', 'glasses': '15'}},
#  {'id': '307', 'seed': {'body': '7', 'head': '216', 'glasses': '9'}},
#  {'id': '308', 'seed': {'body': '4', 'head': '201', 'glasses': '2'}},
#  {'id': '309', 'seed': {'body': '19', 'head': '177', 'glasses': '15'}},
#  {'id': '31', 'seed': {'body': '26', 'head': '108', 'glasses': '5'}},
#  {'id': '310', 'seed': {'body': '25', 'head': '149', 'glasses': '13'}},
#  {'id': '311', 'seed': {'body': '3', 'head': '228', 'glasses': '2'}},
#  {'id': '312', 'seed': {'body': '17', 'head': '202', 'glasses': '5'}},
#  {'id': '313', 'seed': {'body': '4', 'head': '169', 'glasses': '13'}},
#  {'id': '314', 'seed': {'body': '15', 'head': '157', 'glasses': '15'}},
#  {'id': '315', 'seed': {'body': '25', 'head': '219', 'glasses': '16'}},
#  {'id': '316', 'seed': {'body': '25', 'head': '190', 'glasses': '4'}},
#  {'id': '317', 'seed': {'body': '1', 'head': '126', 'glasses': '11'}},
#  {'id': '318', 'seed': {'body': '1', 'head': '63', 'glasses': '12'}},
#  {'id': '319', 'seed': {'body': '13', 'head': '16', 'glasses': '20'}},
#  {'id': '32', 'seed': {'body': '15', 'head': '191', 'glasses': '15'}},
#  {'id': '320', 'seed': {'body': '16', 'head': '196', 'glasses': '10'}},
#  {'id': '321', 'seed': {'body': '14', 'head': '100', 'glasses': '5'}},
#  {'id': '322', 'seed': {'body': '7', 'head': '59', 'glasses': '6'}},
#  {'id': '323', 'seed': {'body': '20', 'head': '215', 'glasses': '2'}},
#  {'id': '324', 'seed': {'body': '4', 'head': '63', 'glasses': '6'}},
#  {'id': '325', 'seed': {'body': '10', 'head': '138', 'glasses': '10'}},
#  {'id': '326', 'seed': {'body': '23', 'head': '190', 'glasses': '18'}},
#  {'id': '327', 'seed': {'body': '13', 'head': '128', 'glasses': '16'}},
#  {'id': '328', 'seed': {'body': '28', 'head': '89', 'glasses': '19'}},
#  {'id': '329', 'seed': {'body': '8', 'head': '134', 'glasses': '4'}},
#  {'id': '33', 'seed': {'body': '27', 'head': '89', 'glasses': '9'}},
#  {'id': '330', 'seed': {'body': '19', 'head': '232', 'glasses': '15'}},
#  {'id': '331', 'seed': {'body': '0', 'head': '57', 'glasses': '10'}},
#  {'id': '332', 'seed': {'body': '26', 'head': '233', 'glasses': '7'}},
#  {'id': '333', 'seed': {'body': '5', 'head': '41', 'glasses': '4'}},
#  {'id': '334', 'seed': {'body': '21', 'head': '50', 'glasses': '18'}},
#  {'id': '335', 'seed': {'body': '27', 'head': '62', 'glasses': '9'}},
#  {'id': '336', 'seed': {'body': '21', 'head': '93', 'glasses': '0'}},
#  {'id': '337', 'seed': {'body': '20', 'head': '95', 'glasses': '4'}},
#  {'id': '338', 'seed': {'body': '1', 'head': '2', 'glasses': '18'}},
#  {'id': '339', 'seed': {'body': '29', 'head': '180', 'glasses': '16'}},
#  {'id': '34', 'seed': {'body': '7', 'head': '17', 'glasses': '17'}},
#  {'id': '340', 'seed': {'body': '15', 'head': '53', 'glasses': '2'}},
#  {'id': '341', 'seed': {'body': '22', 'head': '3', 'glasses': '1'}},
#  {'id': '342', 'seed': {'body': '4', 'head': '63', 'glasses': '0'}},
#  {'id': '343', 'seed': {'body': '27', 'head': '46', 'glasses': '15'}},
#  {'id': '344', 'seed': {'body': '24', 'head': '165', 'glasses': '15'}},
#  {'id': '345', 'seed': {'body': '14', 'head': '23', 'glasses': '14'}},
#  {'id': '346', 'seed': {'body': '8', 'head': '184', 'glasses': '13'}},
#  {'id': '347', 'seed': {'body': '22', 'head': '187', 'glasses': '17'}},
#  {'id': '348', 'seed': {'body': '23', 'head': '211', 'glasses': '13'}},
#  {'id': '349', 'seed': {'body': '26', 'head': '202', 'glasses': '14'}},
#  {'id': '35', 'seed': {'body': '8', 'head': '158', 'glasses': '0'}},
#  {'id': '350', 'seed': {'body': '3', 'head': '99', 'glasses': '4'}},
#  {'id': '351', 'seed': {'body': '3', 'head': '217', 'glasses': '1'}},
#  {'id': '352', 'seed': {'body': '4', 'head': '74', 'glasses': '15'}},
#  {'id': '353', 'seed': {'body': '21', 'head': '224', 'glasses': '19'}},
#  {'id': '354', 'seed': {'body': '20', 'head': '226', 'glasses': '5'}},
#  {'id': '355', 'seed': {'body': '13', 'head': '115', 'glasses': '10'}},
#  {'id': '356', 'seed': {'body': '4', 'head': '116', 'glasses': '4'}},
#  {'id': '357', 'seed': {'body': '7', 'head': '11', 'glasses': '0'}},
#  {'id': '358', 'seed': {'body': '17', 'head': '189', 'glasses': '2'}},
#  {'id': '359', 'seed': {'body': '22', 'head': '129', 'glasses': '19'}},
#  {'id': '36', 'seed': {'body': '2', 'head': '140', 'glasses': '18'}},
#  {'id': '360', 'seed': {'body': '27', 'head': '227', 'glasses': '7'}},
#  {'id': '361', 'seed': {'body': '26', 'head': '132', 'glasses': '4'}},
#  {'id': '362', 'seed': {'body': '5', 'head': '127', 'glasses': '13'}},
#  {'id': '363', 'seed': {'body': '24', 'head': '39', 'glasses': '4'}},
#  {'id': '364', 'seed': {'body': '29', 'head': '83', 'glasses': '20'}},
#  {'id': '365', 'seed': {'body': '1', 'head': '134', 'glasses': '1'}},
#  {'id': '366', 'seed': {'body': '2', 'head': '184', 'glasses': '13'}},
#  {'id': '367', 'seed': {'body': '22', 'head': '177', 'glasses': '14'}},
#  {'id': '368', 'seed': {'body': '10', 'head': '144', 'glasses': '9'}},
#  {'id': '369', 'seed': {'body': '2', 'head': '4', 'glasses': '0'}},
#  {'id': '37', 'seed': {'body': '18', 'head': '222', 'glasses': '6'}},
#  {'id': '370', 'seed': {'body': '3', 'head': '216', 'glasses': '3'}},
#  {'id': '371', 'seed': {'body': '19', 'head': '216', 'glasses': '15'}},
#  {'id': '372', 'seed': {'body': '12', 'head': '216', 'glasses': '15'}},
#  {'id': '373', 'seed': {'body': '24', 'head': '36', 'glasses': '6'}},
#  {'id': '374', 'seed': {'body': '3', 'head': '69', 'glasses': '19'}},
#  {'id': '375', 'seed': {'body': '9', 'head': '55', 'glasses': '18'}},
#  {'id': '376', 'seed': {'body': '0', 'head': '189', 'glasses': '17'}},
#  {'id': '377', 'seed': {'body': '25', 'head': '89', 'glasses': '14'}},
#  {'id': '378', 'seed': {'body': '22', 'head': '88', 'glasses': '3'}},
#  {'id': '379', 'seed': {'body': '19', 'head': '190', 'glasses': '7'}},
#  {'id': '38', 'seed': {'body': '5', 'head': '214', 'glasses': '15'}},
#  {'id': '380', 'seed': {'body': '13', 'head': '0', 'glasses': '10'}},
#  {'id': '381', 'seed': {'body': '22', 'head': '182', 'glasses': '14'}},
#  {'id': '382', 'seed': {'body': '22', 'head': '60', 'glasses': '13'}},
#  {'id': '383', 'seed': {'body': '20', 'head': '146', 'glasses': '18'}},
#  {'id': '384', 'seed': {'body': '29', 'head': '128', 'glasses': '7'}},
#  {'id': '385', 'seed': {'body': '7', 'head': '2', 'glasses': '16'}},
#  {'id': '386', 'seed': {'body': '29', 'head': '214', 'glasses': '5'}},
#  {'id': '387', 'seed': {'body': '0', 'head': '10', 'glasses': '15'}},
#  {'id': '388', 'seed': {'body': '23', 'head': '18', 'glasses': '15'}},
#  {'id': '389', 'seed': {'body': '28', 'head': '86', 'glasses': '10'}},
#  {'id': '39', 'seed': {'body': '21', 'head': '133', 'glasses': '20'}},
#  {'id': '390', 'seed': {'body': '20', 'head': '129', 'glasses': '1'}},
#  {'id': '391', 'seed': {'body': '6', 'head': '94', 'glasses': '0'}},
#  {'id': '392', 'seed': {'body': '21', 'head': '27', 'glasses': '0'}},
#  {'id': '393', 'seed': {'body': '14', 'head': '19', 'glasses': '17'}},
#  {'id': '394', 'seed': {'body': '10', 'head': '34', 'glasses': '7'}},
#  {'id': '395', 'seed': {'body': '20', 'head': '7', 'glasses': '17'}},
#  {'id': '396', 'seed': {'body': '11', 'head': '62', 'glasses': '7'}},
#  {'id': '397', 'seed': {'body': '27', 'head': '184', 'glasses': '4'}},
#  {'id': '398', 'seed': {'body': '14', 'head': '217', 'glasses': '8'}},
#  {'id': '399', 'seed': {'body': '13', 'head': '88', 'glasses': '9'}},
#  {'id': '4', 'seed': {'body': '5', 'head': '231', 'glasses': '5'}},
#  {'id': '40', 'seed': {'body': '12', 'head': '216', 'glasses': '17'}},
#  {'id': '400', 'seed': {'body': '1', 'head': '223', 'glasses': '13'}},
#  {'id': '401', 'seed': {'body': '12', 'head': '20', 'glasses': '6'}},
#  {'id': '402', 'seed': {'body': '24', 'head': '93', 'glasses': '15'}},
#  {'id': '41', 'seed': {'body': '27', 'head': '220', 'glasses': '20'}},
#  {'id': '42', 'seed': {'body': '16', 'head': '71', 'glasses': '5'}},
#  {'id': '43', 'seed': {'body': '21', 'head': '112', 'glasses': '9'}},
#  {'id': '44', 'seed': {'body': '14', 'head': '218', 'glasses': '4'}},
#  {'id': '45', 'seed': {'body': '1', 'head': '110', 'glasses': '19'}},
#  {'id': '46', 'seed': {'body': '8', 'head': '162', 'glasses': '19'}},
#  {'id': '47', 'seed': {'body': '14', 'head': '187', 'glasses': '16'}},
#  {'id': '48', 'seed': {'body': '6', 'head': '4', 'glasses': '2'}},
#  {'id': '49', 'seed': {'body': '25', 'head': '90', 'glasses': '0'}},
#  {'id': '5', 'seed': {'body': '6', 'head': '39', 'glasses': '19'}},
#  {'id': '50', 'seed': {'body': '7', 'head': '68', 'glasses': '16'}},
#  {'id': '51', 'seed': {'body': '8', 'head': '82', 'glasses': '8'}},
#  {'id': '52', 'seed': {'body': '28', 'head': '173', 'glasses': '12'}},
#  {'id': '53', 'seed': {'body': '7', 'head': '99', 'glasses': '3'}},
#  {'id': '54', 'seed': {'body': '26', 'head': '201', 'glasses': '6'}},
#  {'id': '55', 'seed': {'body': '8', 'head': '160', 'glasses': '7'}},
#  {'id': '56', 'seed': {'body': '5', 'head': '233', 'glasses': '0'}},
#  {'id': '57', 'seed': {'body': '19', 'head': '153', 'glasses': '4'}},
#  {'id': '58', 'seed': {'body': '9', 'head': '137', 'glasses': '0'}},
#  {'id': '59', 'seed': {'body': '7', 'head': '110', 'glasses': '16'}},
#  {'id': '6', 'seed': {'body': '17', 'head': '178', 'glasses': '0'}},
#  {'id': '60', 'seed': {'body': '26', 'head': '232', 'glasses': '13'}},
#  {'id': '61', 'seed': {'body': '7', 'head': '152', 'glasses': '0'}},
#  {'id': '62', 'seed': {'body': '5', 'head': '119', 'glasses': '12'}},
#  {'id': '63', 'seed': {'body': '12', 'head': '186', 'glasses': '18'}},
#  {'id': '64', 'seed': {'body': '22', 'head': '128', 'glasses': '19'}},
#  {'id': '65', 'seed': {'body': '23', 'head': '123', 'glasses': '20'}},
#  {'id': '66', 'seed': {'body': '22', 'head': '84', 'glasses': '16'}},
#  {'id': '67', 'seed': {'body': '20', 'head': '7', 'glasses': '19'}},
#  {'id': '68', 'seed': {'body': '24', 'head': '184', 'glasses': '18'}},
#  {'id': '69', 'seed': {'body': '4', 'head': '82', 'glasses': '20'}},
#  {'id': '7', 'seed': {'body': '12', 'head': '126', 'glasses': '9'}},
#  {'id': '70', 'seed': {'body': '21', 'head': '54', 'glasses': '0'}},
#  {'id': '71', 'seed': {'body': '29', 'head': '176', 'glasses': '3'}},
#  {'id': '72', 'seed': {'body': '22', 'head': '90', 'glasses': '6'}},
#  {'id': '73', 'seed': {'body': '24', 'head': '171', 'glasses': '1'}},
#  {'id': '74', 'seed': {'body': '27', 'head': '117', 'glasses': '12'}},
#  {'id': '75', 'seed': {'body': '11', 'head': '53', 'glasses': '12'}},
#  {'id': '76', 'seed': {'body': '28', 'head': '196', 'glasses': '19'}},
#  {'id': '77', 'seed': {'body': '2', 'head': '29', 'glasses': '7'}},
#  {'id': '78', 'seed': {'body': '17', 'head': '158', 'glasses': '2'}},
#  {'id': '79', 'seed': {'body': '13', 'head': '186', 'glasses': '5'}},
#  {'id': '8', 'seed': {'body': '20', 'head': '202', 'glasses': '19'}},
#  {'id': '80', 'seed': {'body': '3', 'head': '76', 'glasses': '10'}},
#  {'id': '81', 'seed': {'body': '2', 'head': '25', 'glasses': '8'}},
#  {'id': '82', 'seed': {'body': '15', 'head': '116', 'glasses': '20'}},
#  {'id': '83', 'seed': {'body': '8', 'head': '205', 'glasses': '18'}},
#  {'id': '84', 'seed': {'body': '12', 'head': '106', 'glasses': '18'}},
#  {'id': '85', 'seed': {'body': '19', 'head': '214', 'glasses': '9'}},
#  {'id': '86', 'seed': {'body': '12', 'head': '165', 'glasses': '2'}},
#  {'id': '87', 'seed': {'body': '24', 'head': '127', 'glasses': '3'}},
#  {'id': '88', 'seed': {'body': '20', 'head': '163', 'glasses': '6'}},
#  {'id': '89', 'seed': {'body': '25', 'head': '55', 'glasses': '19'}},
#  {'id': '9', 'seed': {'body': '2', 'head': '9', 'glasses': '4'}},
#  {'id': '90', 'seed': {'body': '3', 'head': '217', 'glasses': '17'}},
#  {'id': '91', 'seed': {'body': '24', 'head': '83', 'glasses': '2'}},
#  {'id': '92', 'seed': {'body': '5', 'head': '230', 'glasses': '4'}},
#  {'id': '93', 'seed': {'body': '3', 'head': '206', 'glasses': '7'}},
#  {'id': '94', 'seed': {'body': '1', 'head': '226', 'glasses': '15'}},
#  {'id': '95', 'seed': {'body': '16', 'head': '107', 'glasses': '17'}},
#  {'id': '96', 'seed': {'body': '1', 'head': '144', 'glasses': '7'}},
#  {'id': '97', 'seed': {'body': '28', 'head': '69', 'glasses': '17'}},
#  {'id': '98', 'seed': {'body': '13', 'head': '229', 'glasses': '17'}},
#  {'id': '99', 'seed': {'body': '17', 'head': '36', 'glasses': '19'}}]

# %%
seen_heads = set()
seen_glasses = set()
seen_bodies = set()

nouns = [ (int(noun['id']), noun) for noun in data['data']['nouns']]
nouns = sorted(nouns)

# %%
head_ratio = []
glasses_ratio = []
bodies_ratio = []
for noun_id, noun in nouns:
    seen_heads.add(noun['seed']['head'])
    seen_glasses.add(noun['seed']['glasses'])
    seen_bodies.add(noun['seed']['body'])
    
    head_ratio.append(
        len(seen_heads)/TOTAL_HEADS
    )
    glasses_ratio.append(
        len(seen_glasses)/TOTAL_GLASSES
    )
    bodies_ratio.append(
        len(seen_bodies)/TOTAL_BODIES
    )

# %%
plt.figure(figsize=(15,10))
plt.plot(head_ratio, label="Fraction of heads seen")
plt.plot(glasses_ratio, label="Fraction of glasses seen")
plt.plot(bodies_ratio, label="Fraction of bodies seen")
plt.title("Seen Noun Trait Stats vs Time")
plt.xlabel("Nouns")
plt.ylabel("Fraction of trait seen")
plt.legend()
plt.show()
